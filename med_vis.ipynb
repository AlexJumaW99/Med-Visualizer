# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('medical_examination.csv')
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ## Add an overweight column to the data. To determine if a person is overweight, first calculate their BMI by dividing their weight in kilograms by the square of their height in meters. If that value is > 25 then the person is overweight. Use the value 0 for NOT overweight and the value 1 for overweight.

# %%
def is_overweight(weight, height):
    bmi = weight/((height/100)**2)
    if bmi > 25:
        return 1
    else:
        return 0

is_overweight(130,180)
# Out:
# 1

# %%
df['overweight'] = np.vectorize(is_overweight) (df['weight'], df['height'])
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
df['overweight'].value_counts()
# Out:
# 1    43546
# 0    26454
# Name: overweight, dtype: int64

# %% [markdown]
# ## Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol or gluc is 1, make the value 0. If the value is more than 1, make the value 1.

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
df['cholesterol'] = df['cholesterol'].apply(lambda x: 0 if x==1 else 1)
#df['cholesterol'].value_counts()
df['gluc'] = df['gluc'].apply(lambda x: 0 if x==1 else 1)
#df['gluc'].value_counts()

# %% [markdown]
# ## Convert the data into long format and create a chart that shows the value counts of the categorical features using seaborn's catplot(). The dataset should be split by 'Cardio' so there is one chart for each cardio value. The chart should look like examples/Figure_1.png.

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# 69995      1     0       1       0           1
# 69996      0     0       1       1           1
# 69997      0     1       0       1           1
# 69998      0     0       0       1           1
# 69999      0     0       1       0           0

# %%
df2 = df.copy()
df2
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df2 = df2.melt(id_vars='cardio', value_vars=['cholesterol','gluc','smoke','alco','active','overweight'])

# %%
df2
# Out:
#         cardio     variable  value
# 0            0  cholesterol      0
# 1            1  cholesterol      1
# 2            1  cholesterol      1
# 3            1  cholesterol      0
# 4            0  cholesterol      0
# ...        ...          ...    ...
# 419995       0   overweight      1
# 419996       1   overweight      1
# 419997       1   overweight      1
# 419998       1   overweight      1
# 419999       0   overweight      0
#
# [420000 rows x 3 columns]

# %%
plt.figure(figsize=(15,6), dpi=150)
sns.catplot(data=df2, x='variable', kind='count', col='cardio', hue='value')

# %% [markdown]
# ## Clean the data. Filter out the following patient segments that represent incorrect data:
# 1. diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))
# 2. height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))
# 3. height is more than the 97.5th percentile
# 4. weight is less than the 2.5th percentile
# 5. weight is more than the 97.5th percentile

# %%
df = df[(df['ap_lo'] <= df['ap_hi']) &
        (df['height'] >= df['height'].quantile(0.025)) &
        (df['height'] <= df['height'].quantile(0.975)) &
        (df['weight'] >= df['weight'].quantile(0.025)) &
        (df['weight'] <= df['weight'].quantile(0.975))]
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699       1     172    70.0    130     90            0     0
# 69994  99992  21074       1     165    80.0    150     80            0     0
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %% [markdown]
# ## Create a correlation matrix using the dataset. Plot the correlation matrix using seaborn's heatmap(). Mask the upper triangle. The chart should look like examples/Figure_2.png.

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.002507  0.003426  0.000326  0.000149  0.003492
# age          0.002507  1.000000 -0.018132 -0.076932  0.070168  0.018689
# gender       0.003426 -0.018132  1.000000  0.505785  0.129979  0.005063
# height       0.000326 -0.076932  0.505785  1.000000  0.251503  0.004586
# weight       0.000149  0.070168  0.129979  0.251503  1.000000  0.027030
# ap_hi        0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo        0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol  0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc         0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke       -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco        -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# active       0.005891 -0.011445  0.007864 -0.005661 -0.014430 -0.000222
# ...

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.heatmap(data=df.corr(), annot=True, lw=2)
# Out:
# <AxesSubplot:>

# %%
df_corr = df.corr()
lt = df_corr.where(np.tril(np.ones(df_corr.shape)).astype('bool'))
lt
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000       NaN       NaN       NaN       NaN       NaN
# age          0.002507  1.000000       NaN       NaN       NaN       NaN
# gender       0.003426 -0.018132  1.000000       NaN       NaN       NaN
# height       0.000326 -0.076932  0.505785  1.000000       NaN       NaN
# weight       0.000149  0.070168  0.129979  0.251503  1.000000       NaN
# ap_hi        0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo        0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol  0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc         0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke       -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco        -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# active       0.005891 -0.011445  0.007864 -0.005661 -0.014430 -0.000222
# ...

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.heatmap(data=lt, annot=True)
# Out:
# <AxesSubplot:>
